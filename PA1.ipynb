# %% [markdown]
# <a href="https://colab.research.google.com/github/cmyhre2/CS150_Spring2025/blob/Programming-Assignments/PA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Chris Myhre  - Markdown Practice

# %% [markdown]
# ###About Me
# My name is Chris and I see myself as an introverted kind of person. Some interests of mine are video games, programming and nature.

# %% [markdown]
# ### Course Activities
# - Programming Assignments (5)
# - Quizzes (4)
# - Attendence / Participation
# - Mid-Term Exams (2)
# - Project (2)

# %% [markdown]
# ###Course Modules
# 1. Intro to Python
# 2. Lists & Tuples Part 1
# 3. If Statements
# 4. While & For Loops
# 5. Lists & Tuples Part 2
# 6. Dictionaries
# 7. Sets, Functions, Libraries
# 8. Classes & Exceptions in Python
# 9. NumPy Library
# 10. DataFrames & Files

# %% [markdown]
# The primary programming language that is tought in this course is **Python**.

# %% [markdown]
# This file was made in *Google Colab*.

# %% [markdown]
# Something I did today was `this assignment`.

# %% [markdown]
# My GitHub Repository [Link](https://github.com/cmyhre2/CS150_Spring2025)

# %% [markdown]
# ![bellarmine-university-seal.png](data:image/png;base64,...)

# %% [markdown]
# In this assignment, I learned how to use Markdown to show images, bold, italicize and highlight text. Also took another look at the course assignments I'll be expected to do and the modules this class will go through.
